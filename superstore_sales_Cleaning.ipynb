# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_excel('/content/Sample - Superstore.xls')
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df=df.drop(('Row ID'),axis=1)

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   datetime64[ns]
#  2   Ship Date      9994 non-null   datetime64[ns]
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  Postal Code    9994 non-null   int64
#  11  Region         9994 non-null   object
#  12  Product ID     9994 non-null   object
#  13  Category       9994 non-null   object
#  14  Sub-Category   9994 non-null   object
#  15  Product Name   9994 non-null   object
#  16  Sales          9994 non-null   float64
# ...

# %%
a = df['Order Date'].dtype

# %%
type(a)
# Out:
# numpy.dtypes.DateTime64DType

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
# # Extract Month and Year fro Order Date
# df['Month'] = df['Order Date'].dt.month
# df['Year'] = df['Order Date'].dt.year

# %%
df['Month-Year'] = df['Order Date'].dt.strftime('%b-%Y')

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    ...  Region       Product ID         Category Sub-Category  \
# ...

# %%
df[df.duplicated()==True]
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3406  US-2014-150119 2014-04-23 2014-04-27  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  ...  Region  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio  ...    East
#
#            Product ID   Category Sub-Category  \
# 3406  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit  Month-Year
# 3406       0.3 -12.0588    Apr-2014
#
# [1 rows x 21 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df[df['Order ID']== 'US-2014-150119']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119 2014-04-23 2014-04-27  Standard Class    LB-16795
# 3407  US-2014-150119 2014-04-23 2014-04-27  Standard Class    LB-16795
# 3408  US-2014-150119 2014-04-23 2014-04-27  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  ...  Region  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio  ...    East
# 3407  Laurel Beltran  Home Office  United States  Columbus  Ohio  ...    East
# 3408  Laurel Beltran  Home Office  United States  Columbus  Ohio  ...    East
#
#            Product ID         Category Sub-Category  \
# 3405  FUR-CH-10002965        Furniture       Chairs
# 3407  OFF-BI-10000145  Office Supplies      Binders
# 3408  FUR-FU-10002191        Furniture  Furnishings
#
#                                            Product Name    Sales  Quantity  \
# 3405  Global Leather Highback Executive Chair with P...  281.372         2
# ...

# %%
# Step 3: Handle missing values
print("\nMissing Values Before:")
print(df.isnull().sum())
# Out:
# Missing Values Before:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Month-Year       0
# dtype: int64

# %%
df.sample(10)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 5106  CA-2015-147102 2015-09-19 2015-09-26  Standard Class    NH-18610
# 28    US-2015-150630 2015-09-17 2015-09-21  Standard Class    TB-21520
# 9295  CA-2017-161340 2017-05-28 2017-06-01  Standard Class    AM-10360
# 7010  US-2014-135881 2014-05-23 2014-05-27  Standard Class    GT-14710
# 5643  CA-2015-166604 2015-05-15 2015-05-20    Second Class    AH-10690
# 4706  CA-2016-158435 2016-05-17 2016-05-18     First Class    AG-10900
# 7811  CA-2016-134334 2016-02-14 2016-02-15     First Class    DK-13090
# 9708  CA-2016-161746 2016-10-21 2016-10-27  Standard Class    CS-11950
# 8125  CA-2015-137064 2015-02-06 2015-02-13  Standard Class    TS-21655
# 310   CA-2016-142902 2016-09-12 2016-09-14    Second Class    BP-11185
#
#         Customer Name    Segment        Country           City         State  \
# 5106    Nicole Hansen  Corporate  United States       Columbus       Georgia
# ...

# %%
df.to_csv('clean_data_superstore.csv',index=False)
